# %%
import h5py
from typing import Callable
from typing import List
from typing import Optional
from typing import Tuple 

import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision.transforms import transforms
import pytorch_lightning as pl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-c08b0ecb4674> in <module>
#       9 from torch.utils.data import Dataset
#      10 from torchvision.transforms import transforms
# ---> 11 import pytorch_lightning as pl
#
# ModuleNotFoundError: No module named 'pytorch_lightning'

# %%
class AudioDataset(Dataset):
    def __init__(self, hdf5_file_path: str, max_num_files: Optional[int], audio_transforms: Callable):
        super().__init__()
        self.hdf5_file_path = hdf5_file_path
        self.audio_transforms = audio_transforms
        self.max_num_files = max_num_files
        self.file = h5py.File(hdf5_file_path, "r")
        self.keys = list(self.file["file"].keys())  # Get all keys (file names)

        if self.max_num_files is not None:
            self.keys = self.keys[:self.max_num_files]

    def __getitem__(self, index: int):
        key = self.keys[index]
        audio_signal = self.file["file"][key]["signal"][()]  # Read the audio signal
        label1 = self.file["file"][key]["label1"][()].decode("utf-8")  # Read label1
        label2 = self.file["file"][key]["label2"][()].decode("utf-8")  # Read label2

        return audio_signal, label1, label2

    def __len__(self):
        return len(self.keys)

# %%
#!pip install pytorch_lightning
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# absl-py                   0.11.0
# aiohttp                   2.3.10
# aiosignal                 1.3.1
# annotated-types           0.5.0
# anyio                     3.7.1
# appdirs                   1.4.4
# asttokens                 2.2.1
# async-timeout             3.0.1
# attrs                     23.1.0
# backcall                  0.2.0
# brotlipy                  0.7.0
# build                     0.10.0
# CacheControl              0.12.14
# cachetools                4.2.0
# certifi                   2020.12.5
# cffi                      1.15.1
# chardet                   4.0.0
# charset-normalizer        2.0.4
# cleo                      2.0.1
# click                     8.1.5
# colorama                  0.4.6
# contourpy                 1.1.0
# crashtest                 0.4.1
# cryptography              39.0.1
# cycler                    0.11.0
# decorator                 5.1.1
# distlib                   0.3.6
# docker-pycreds            0.4.0
# dulwich                   0.21.5
# exceptiongroup            1.1.2
# executing                 1.2.0
# fastapi                   0.100.0
# filelock                  3.12.2
# fonttools                 4.41.0
# frozenlist                1.3.3
# fsspec                    2023.6.0
# future                    0.18.3
# gitdb                     4.0.5
# GitPython                 3.1.32
# gmpy2                     2.1.2
# google-auth               2.22.0
# google-auth-oauthlib      1.0.0
# grpcio                    1.56.0
# h5py                      3.9.0
# html5lib                  1.1
# idna                      2.10
# idna-ssl                  1.1.0
# importlib-metadata        6.8.0
# importlib-resources       6.0.0
# installer                 0.7.0
# ipython                   8.12.2
# jaraco.classes            3.3.0
# jedi                      0.18.2
# jeepney                   0.8.0
# Jinja2                    3.1.2
# jsonschema                4.18.2
# jsonschema-specifications 2023.6.1
# keyring                   23.13.1
# kiwisolver                1.4.4
# lightning-utilities       0.9.0
# lockfile                  0.12.2
# Markdown                  3.3.3
# MarkupSafe                2.1.1
# matplotlib                3.7.2
# matplotlib-inline         0.1.6
# mkl-fft                   1.3.6
# mkl-random                1.2.2
# mkl-service               2.4.0
# more-itertools            9.1.0
# mpmath                    1.2.1
# msgpack                   1.0.5
# multidict                 5.1.0
# networkx                  2.8.4
# numpy                     1.24.3
# oauthlib                  3.1.0
# packaging                 23.1
# parso                     0.8.3
# pathtools                 0.1.2
# pexpect                   4.8.0
# pickleshare               0.7.5
# Pillow                    9.4.0
# pip                       23.1.2
# pkginfo                   1.9.6
# pkgutil_resolve_name      1.3.10
# platformdirs              3.8.1
# poetry                    1.5.1
# poetry-core               1.6.1
# poetry-plugin-export      1.4.0
# prompt-toolkit            3.0.39
# protobuf                  4.23.4
# psutil                    5.9.5
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# pyasn1                    0.4.8
# pyasn1-modules            0.2.8
# pycparser                 2.21
# pydantic                  2.0.3
# pydantic_core             2.3.0
# Pygments                  2.15.1
# pyOpenSSL                 23.0.0
# pyparsing                 3.0.9
# pyproject_hooks           1.0.0
# PySocks                   1.7.1
# python-dateutil           2.8.2
# pytorch-lightning         1.1.4
# PyYAML                    6.0
# rapidfuzz                 2.15.1
# referencing               0.29.1
# requests                  2.25.1
# requests-oauthlib         1.3.0
# requests-toolbelt         1.0.0
# rpds-py                   0.8.10
# rsa                       4.7
# SecretStorage             3.3.3
# sentry-sdk                1.28.1
# setproctitle              1.3.2
# setuptools                67.8.0
# shellingham               1.5.0.post1
# six                       1.15.0
# smmap                     3.0.4
# sniffio                   1.3.0
# soundfile                 0.12.1
# stack-data                0.6.2
# starlette                 0.27.0
# sympy                     1.11.1
# tensorboard               2.13.0
# tensorboard-data-server   0.7.1
# tensorboard-plugin-wit    1.7.0
# tomli                     2.0.1
# tomlkit                   0.11.8
# torch                     2.0.1
# torchaudio                2.0.2
# torchmetrics              0.11.4
# torchvision               0.15.2
# tqdm                      4.65.0
# traitlets                 5.9.0
# triton                    2.0.0
# trove-classifiers         2023.7.6
# typing_extensions         4.6.3
# urllib3                   1.26.16
# virtualenv                20.23.1
# wandb                     0.15.5
# wcwidth                   0.2.6
# webencodings              0.5.1
# Werkzeug                  1.0.1
# wheel                     0.38.4
# yarl                      1.6.3
# zipp                      3.16.0

# %%
class AudioDataModule(pl.LightningDataModule):
    def __init__(
        self,
        hdf5_file_path: str,
        train_batch_size: int,
        val_batch_size: int,
        audio_transforms: Callable,
        num_workers: int,
        num_train_files: Optional[int] = None,
        num_val_files: Optional[int] = None,
    ):
        super().__init__()
        self.hdf5_file_path = hdf5_file_path
        self.train_batch_size = train_batch_size
        self.val_batch_size = val_batch_size
        self.audio_transforms = audio_transforms
        self.num_workers = num_workers
        self.num_train_files = num_train_files
        self.num_val_files = num_val_files

        self.train_dataset = AudioDataset(
            hdf5_file_path=self.hdf5_file_path,
            max_num_files=self.num_train_files,
            audio_transforms=self.audio_transforms,
        )
        self.val_dataset = AudioDataset(
            hdf5_file_path=self.hdf5_file_path,
            max_num_files=self.num_val_files,
            audio_transforms=self.audio_transforms,
        )

    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.train_batch_size,
            shuffle=True,
            num_workers=self.num_workers,
            pin_memory=True,
        )

    def val_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.val_batch_size,
            shuffle=False,
            num_workers=self.num_workers,
            pin_memory=True,
        )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f3963f8bcb45> in <module>
# ----> 1 class AudioDataModule(pl.LightningDataModule):
#       2     def __init__(
#       3         self,
#       4         hdf5_file_path: str,
#       5         train_batch_size: int,
#
# NameError: name 'pl' is not defined

# %%
class AudioTransforms(object):
    def __init__(self, resolution: Tuple[int,int]):
        self.transforms=transforms.Compose(
            [
                transforms.ToTensor(),
                transforms.Lambda(lambda X: 2*X-1.0),
                transforms.Resize(resolution),
            ]
        )
    def __call__(self,input, *args, **kwargs):
        return self.transforms(input)

# %%
audio_data_module = AudioDataModule(
    hdf5_file_path='/om2/user//schen77/overlapping_dataset_test.h5',
    train_batch_size=2,
    val_batch_size=2,
    audio_transforms=AudioTransforms(resolution=(128, 128)),
    num_workers=4,
    num_train_files=50,  
    num_val_files=10,    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-af8378a03483> in <module>
# ----> 1 audio_data_module = AudioDataModule(
#       2     hdf5_file_path='/om2/user//schen77/overlapping_dataset_test.h5',
#       3     train_batch_size=2,
#       4     val_batch_size=2,
#       5     audio_transforms=AudioTransforms(resolution=(128, 128)),
#
# NameError: name 'AudioDataModule' is not defined

# %%
# Load the data using the data module
train_loader = audio_data_module.train_dataloader()
val_loader = audio_data_module.val_dataloader()

# Iterate over the data loaders to access the data
for batch_idx, (audio_signal, label1, label2) in enumerate(train_loader):
    # process data
    print(f"Batch {batch_idx}: Audio Signal Shape: {audio_signal.shape}, Label1: {label1}, Label2: {label2}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b6e442d373cd> in <module>
#       1 # Load the data using the data module
# ----> 2 train_loader = audio_data_module.train_dataloader()
#       3 val_loader = audio_data_module.val_dataloader()
#       4
#       5 # Iterate over the data loaders to access the data
#
# NameError: name 'audio_data_module' is not defined
